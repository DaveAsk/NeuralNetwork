# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
t = np.arange(0, 2000)
X = np.sin(0.01 * t)

# %%
plt.plot(X)

# %%
X[:10]
# Out:
# array([0.        , 0.00999983, 0.01999867, 0.0299955 , 0.03998933,
#        0.04997917, 0.05996401, 0.06994285, 0.07991469, 0.08987855])

# %%
X_train, X_test = X[:1500], X[1500:]

# %%
model = Sequential()
model.add(SimpleRNN(units=64, activation='tanh'))
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='mean_absolute_error', optimizer='adam', metrics='accuracy')

# %%
XT, yT = [], []
for i in range(len(X_train) - 15):
    d = i + 15
    XT.append(X_train[i:d,])
    yT.append(X_train[d])

# %%
Xt, yt = [], []
for i in range(len(X_test) - 15):
    d = i + 15
    Xt.append(X_test[i:d,])
    yt.append(X_test[d])

# %%
XT = np.array(XT)
Xt = np.array(Xt)

# %%
XT.shape
# Out:
# (1485, 15)

# %%
XT[2]
# Out:
# array([0.01999867, 0.0299955 , 0.03998933, 0.04997917, 0.05996401,
#        0.06994285, 0.07991469, 0.08987855, 0.09983342, 0.1097783 ,
#        0.11971221, 0.12963414, 0.13954311, 0.14943813, 0.15931821])

# %%
yT[2]
# Out:
# 0.16918234906699603

# %%
XT = np.reshape(XT, (XT.shape[0], XT.shape[1], 1))
Xt = np.reshape(Xt, (Xt.shape[0], Xt.shape[1], 1))

# %%
XT.shape
# Out:
# (1485, 15, 1)

# %%
XT[0]
# Out:
# array([[0.        ],
#        [0.00999983],
#        [0.01999867],
#        [0.0299955 ],
#        [0.03998933],
#        [0.04997917],
#        [0.05996401],
#        [0.06994285],
#        [0.07991469],
#        [0.08987855],
#        [0.09983342],
#        [0.1097783 ],
#        [0.11971221],
#        [0.12963414],
#        [0.13954311]])

# %%
yT = np.array(yT)
yt = np.array(yt)

# %%
history = model.fit(XT, yT, epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 75/75 [==============================] - 4s 7ms/step - loss: 0.0557 - accuracy: 0.0000e+00
# Epoch 2/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 0.0000e+00
# Epoch 3/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0099 - accuracy: 0.0000e+00
# Epoch 4/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.0000e+00
# Epoch 5/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0090 - accuracy: 0.0000e+00
# Epoch 6/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.0000e+00
# Epoch 7/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0061 - accuracy: 0.0000e+00
# Epoch 8/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.0000e+00
# Epoch 9/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.0000e+00
# Epoch 10/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.0000e+00
# Epoch 11/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.0000e+00
# Epoch 12/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0074 - accuracy: 0.0000e+00
# Epoch 13/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0078 - accuracy: 0.0000e+00
# Epoch 14/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.0000e+00
# Epoch 15/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0051 - accuracy: 0.0000e+00
# Epoch 16/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.0000e+00
# Epoch 17/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.0000e+00
# Epoch 18/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.0000e+00
# Epoch 19/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.0000e+00
# Epoch 20/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0053 - accuracy: 0.0000e+00
# Epoch 21/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.0000e+00
# Epoch 22/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0055 - accuracy: 0.0000e+00
# Epoch 23/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.0000e+00
# Epoch 24/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0043 - accuracy: 0.0000e+00
# Epoch 25/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.0000e+00
# Epoch 26/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.0000e+00
# Epoch 27/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.0000e+00
# Epoch 28/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0041 - accuracy: 0.0000e+00
# Epoch 29/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.0000e+00
# Epoch 30/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.0000e+00
# Epoch 31/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.0000e+00
# Epoch 32/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0043 - accuracy: 0.0000e+00
# Epoch 33/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.0000e+00
# Epoch 34/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0034 - accuracy: 0.0000e+00
# Epoch 35/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 0.0000e+00
# Epoch 36/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0036 - accuracy: 0.0000e+00
# Epoch 37/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.0000e+00
# Epoch 38/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0038 - accuracy: 0.0000e+00
# Epoch 39/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.0000e+00
# Epoch 40/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.0000e+00
# Epoch 41/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0021 - accuracy: 0.0000e+00
# Epoch 42/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0033 - accuracy: 0.0000e+00
# Epoch 43/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.0000e+00
# Epoch 44/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0028 - accuracy: 0.0000e+00
# Epoch 45/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.0000e+00
# Epoch 46/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0040 - accuracy: 0.0000e+00
# Epoch 47/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.0000e+00
# Epoch 48/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0022 - accuracy: 0.0000e+00
# Epoch 49/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.0000e+00
# Epoch 50/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.0000e+00
# Epoch 51/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.0000e+00
# Epoch 52/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.0000e+00
# Epoch 53/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.0000e+00
# Epoch 54/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.0000e+00
# Epoch 55/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.0000e+00
# Epoch 56/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.0000e+00
# Epoch 57/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.0000e+00
# Epoch 58/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.0000e+00
# Epoch 59/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.0000e+00
# Epoch 60/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.0000e+00
# Epoch 61/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0025 - accuracy: 0.0000e+00
# Epoch 62/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.0000e+00
# Epoch 63/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.0000e+00
# Epoch 64/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.0000e+00
# Epoch 65/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.0000e+00
# Epoch 66/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.0000e+00
# Epoch 67/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.0000e+00
# Epoch 68/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.0000e+00
# Epoch 69/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.0000e+00
# Epoch 70/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0025 - accuracy: 0.0000e+00
# Epoch 71/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.0000e+00
# Epoch 72/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.0000e+00
# Epoch 73/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0023 - accuracy: 0.0000e+00
# Epoch 74/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0021 - accuracy: 0.0000e+00
# Epoch 75/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.0000e+00
# Epoch 76/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.0000e+00
# Epoch 77/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.0000e+00
# Epoch 78/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.0000e+00
# Epoch 79/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.0000e+00
# Epoch 80/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.0000e+00
# Epoch 81/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0023 - accuracy: 0.0000e+00
# Epoch 82/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.0000e+00
# Epoch 83/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.0000e+00
# Epoch 84/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.0000e+00
# Epoch 85/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0020 - accuracy: 0.0000e+00
# Epoch 86/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.0000e+00
# Epoch 87/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0022 - accuracy: 0.0000e+00
# Epoch 88/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.0000e+00
# Epoch 89/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0021 - accuracy: 0.0000e+00
# Epoch 90/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.0000e+00
# Epoch 91/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0017 - accuracy: 0.0000e+00
# Epoch 92/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 0.0000e+00
# Epoch 93/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.0000e+00
# Epoch 94/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.0000e+00
# Epoch 95/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0026 - accuracy: 0.0000e+00
# Epoch 96/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0022 - accuracy: 0.0000e+00
# Epoch 97/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.0000e+00
# Epoch 98/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.0000e+00
# Epoch 99/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.0000e+00
# Epoch 100/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 0.0000e+00

# %%
model.evaluate(Xt, yt)
# Out:
# 16/16 [==============================] - 1s 4ms/step - loss: 0.0012 - accuracy: 0.0000e+00
# [0.0012363235000520945, 0.0]

# %%
XTPredicted = model.predict(XT)
XtPredicted = model.predict(Xt)
XFinal = np.concatenate([XTPredicted, XtPredicted], axis=0)
# Out:
# 47/47 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 0s 4ms/step

# %%
plt.plot(X, color='red')
plt.plot(XFinal, color='blue')
